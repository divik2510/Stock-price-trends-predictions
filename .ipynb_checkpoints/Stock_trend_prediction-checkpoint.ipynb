# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
df = pd.read_csv('REL_train.csv')
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2017-01-02   536.910645   539.882446   531.140320   537.455444
# 1     2017-01-03   539.808167   543.349609   535.474243   539.585266
# 2     2017-01-04   541.318848   541.368347   527.153137   528.564758
# 3     2017-01-05   530.471680   534.879883   529.357239   533.641602
# 4     2017-01-06   532.056641   537.405945   531.511780   532.428101
# ...          ...          ...          ...          ...          ...
# 1230  2021-12-24  2370.000000  2392.000000  2337.550049  2372.800049
# 1231  2021-12-27  2361.550049  2378.000000  2348.100098  2370.250000
# 1232  2021-12-28  2375.600098  2404.850098  2373.050049  2398.399902
# 1233  2021-12-29  2391.000000  2419.000000  2382.100098  2402.500000
# 1234  2021-12-30  2400.000000  2404.949951  2345.600098  2359.100098
#
#         Adj Close    Volume
# 0      523.695190   3275674
# 1      525.770508   2969384
# 2      515.032166   4796129
# ...

# %%
plt.figure(figsize=(12,6),dpi = 200)
plt.plot(df['Open'])

# %%
sum(df['Open'].isnull())
# Out:
# 0

# %%
len(df['Open'])
# Out:
# 1235

# %%
df = df['Open'].dropna()

# %%
df.columns = ['Open']
df
# Out:
# 0        536.910645
# 1        539.808167
# 2        541.318848
# 3        530.471680
# 4        532.056641
#            ...
# 1230    2370.000000
# 1231    2361.550049
# 1232    2375.600098
# 1233    2391.000000
# 1234    2400.000000
# Name: Open, Length: 1235, dtype: float64

# %%
len(df)
# Out:
# 1235

# %%
x = np.array(df)
x
# Out:
# array([ 536.910645,  539.808167,  541.318848, ..., 2375.600098,
#        2391.      , 2400.      ])

# %%
x = x.reshape(-1,1)

# %%
x
# Out:
# array([[ 536.910645],
#        [ 539.808167],
#        [ 541.318848],
#        ...,
#        [2375.600098],
#        [2391.      ],
#        [2400.      ]])

# %%
sc = MinMaxScaler(feature_range = (0, 1))
scaled_x = sc.fit_transform(x)

# %%
scaled_x
# Out:
# array([[0.01482139],
#        [0.01611549],
#        [0.01679019],
#        ...,
#        [0.83602241],
#        [0.84290036],
#        [0.84691996]])

# %%
X_train = []
y_train = []
for i in range(200,1235):
    X_train.append(scaled_x[i-200:i, 0])
    y_train.append(scaled_x[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train
# Out:
# array([[0.01482139, 0.01611549, 0.01679019, ..., 0.16321213, 0.18020141,
#         0.17891838],
#        [0.01611549, 0.01679019, 0.0119456 , ..., 0.18020141, 0.17891838,
#         0.19431491],
#        [0.01679019, 0.0119456 , 0.01265348, ..., 0.17891838, 0.19431491,
#         0.19095245],
#        ...,
#        [0.73794395, 0.74352674, 0.75759536, ..., 0.83530777, 0.83352127,
#         0.82974733],
#        [0.74352674, 0.75759536, 0.76072172, ..., 0.83352127, 0.82974733,
#         0.83602241],
#        [0.75759536, 0.76072172, 0.75536225, ..., 0.82974733, 0.83602241,
#         0.84290036]])

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train
# Out:
# array([[[0.01482139],
#         [0.01611549],
#         [0.01679019],
#         ...,
#         [0.16321213],
#         [0.18020141],
#         [0.17891838]],
#
#        [[0.01611549],
#         [0.01679019],
#         [0.0119456 ],
#         ...,
#         [0.18020141],
#         [0.17891838],
#         [0.19431491]],
#
#        [[0.01679019],
#         [0.0119456 ],
#         [0.01265348],
#         ...,
#         [0.17891838],
#         [0.19431491],
#         [0.19095245]],
#
#        ...,
#
#        [[0.73794395],
#         [0.74352674],
#         [0.75759536],
#         ...,
#         [0.83530777],
#         [0.83352127],
#         [0.82974733]],
#
#        [[0.74352674],
#         [0.75759536],
#         [0.76072172],
#         ...,
#         [0.83352127],
#         [0.82974733],
#         [0.83602241]],
#
#        [[0.75759536],
#         [0.76072172],
#         [0.75536225],
#         ...,
#         [0.82974733],
#         [0.83602241],
#         [0.84290036]]])

# %%
y_train
# Out:
# array([0.19431491, 0.19095245, 0.19090821, ..., 0.83602241, 0.84290036,
#        0.84691996])

# %%
regressor = Sequential()

# %%
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 18s 235ms/step - loss: 0.0448
# Epoch 2/100
# 33/33 [==============================] - 8s 230ms/step - loss: 0.0060
# Epoch 3/100
# 33/33 [==============================] - 8s 232ms/step - loss: 0.0061
# Epoch 4/100
# 33/33 [==============================] - 8s 231ms/step - loss: 0.0056
# Epoch 5/100
# 33/33 [==============================] - 8s 250ms/step - loss: 0.0047
# Epoch 6/100
# 33/33 [==============================] - 8s 242ms/step - loss: 0.0045
# Epoch 7/100
# 33/33 [==============================] - 8s 242ms/step - loss: 0.0043
# Epoch 8/100
# 33/33 [==============================] - 8s 236ms/step - loss: 0.0044
# Epoch 9/100
# 33/33 [==============================] - 8s 232ms/step - loss: 0.0045
# Epoch 10/100
# 33/33 [==============================] - 8s 230ms/step - loss: 0.0043
# Epoch 11/100
# 33/33 [==============================] - 8s 230ms/step - loss: 0.0041
# Epoch 12/100
# ...

# %%
df_test = pd.read_csv('REL_test.csv')
real_openprice = df_test.iloc[:, 1:2].values

# %%
df_test
# Out:
#           Date         Open         High          Low        Close  \
# 0   2022-01-03  2365.000000  2407.949951  2363.550049  2403.850098
# 1   2022-01-04  2415.899902  2461.000000  2404.000000  2458.100098
# 2   2022-01-05  2462.000000  2477.000000  2432.949951  2469.600098
# 3   2022-01-06  2451.199951  2454.000000  2409.000000  2416.500000
# 4   2022-01-07  2430.949951  2458.050049  2411.550049  2436.000000
# ..         ...          ...          ...          ...          ...
# 95  2022-05-24  2607.000000  2638.000000  2597.699951  2615.850098
# 96  2022-05-25  2635.000000  2656.699951  2601.500000  2612.000000
# 97  2022-05-26  2624.399902  2634.899902  2548.000000  2587.100098
# 98  2022-05-27  2593.050049  2605.149902  2540.100098  2575.100098
# 99  2022-05-30  2615.000000  2674.000000  2594.199951  2664.800049
#
#       Adj Close   Volume
# 0   2403.850098  2502073
# 1   2458.100098  5006225
# 2   2469.600098  5373618
# 3   2416.500000  6667483
# 4   2436.000000  6051239
# ...

# %%
test_dataset = scaled_x
X_test = []
for j in range(200,200+len(df_test)):
    inputs = test_dataset[j-200:j,0]
    inputs = np.array(inputs)
    X_test.append(inputs)
    
#     inputs = test_dataset[-200:]
#     inputs = np.reshape(inputs,(inputs.shape[0],inputs.shape[1],1))
# #     inputs = inputs.reshape(-1,1)
#     for i in range(1):
#         X_test.append(inputs)
# #     X_test_arr = np.array(X_test)
# #     X_test_dup = np.reshape(X_test_arr, (X_test_arr.shape[0], X_test_arr.shape[1], 1))

#     predicted_stock_price = regressor.predict(X_test[-1])
#     predicted_stock_price = sc.inverse_transform(predicted_stock_price)
#     print(predicted_stock_price)
# #     np.append(test_dataset,predicted_stock_price[-1][0])

# %%
# df_total = df
# X_test = []
# for j in range(100):
#     inputs = df_total[-200:].values
#     print(inputs)
#     inputs = inputs.reshape(-1,1)
#     for i in range(200+j,200+j+1):
#         X_test.append(inputs[i-200:i,0])
# #         print('x_test',X_test)
#     X_test_arr = np.array(X_test)
#     X_test_dup = np.reshape(X_test_arr, (X_test_arr.shape[0], X_test_arr.shape[1], 1))
# #     print(X_test_dup,'xdup')
#     predicted_stock_price = regressor.predict(X_test_dup)
#     predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# #     print(predicted_stock_price,'pred')
#     df1 = predicted_stock_price[-1]
#     df2 = np.array(df1)
#     df3 = pd.DataFrame(df2)
#     df_total = pd.concat([df_total,df3])

# %%
plt.plot(real_openprice, color = 'red', label = 'Real Reliance Stock Price')
plt.plot(X_test[-1][100:], color = 'blue', label = 'Predicted Reliance Stock Price')
plt.title('Reliance Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Reliance Stock Price')
plt.legend()
